# %%
import pandas as pd

# %%
articles = pd.read_csv("wikispeedia_paths-and-graph/articles.tsv", sep='\t', skiprows=11, header=None, encoding="UTF-8")
articles.columns = ['article']
articles
# Out:
#                                article
# 0     %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 1                           %C3%85land
# 2                   %C3%89douard_Manet
# 3                            %C3%89ire
# 4           %C3%93engus_I_of_the_Picts
# ...                                ...
# 4599                           Zionism
# 4600                         Zirconium
# 4601                         Zoroaster
# 4602                      Zuid-Gelders
# 4603                              Zulu
#
# [4604 rows x 1 columns]

# %%
categories = pd.read_csv("wikispeedia_paths-and-graph/categories.tsv", sep='\t', skiprows=12, header=None)
categories.columns = ['article', 'category']
categories
# Out:
#                                article  \
# 0     %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 1     %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 2                           %C3%85land
# 3                           %C3%85land
# 4                   %C3%89douard_Manet
# ...                                ...
# 5199                         Zirconium
# 5200                         Zoroaster
# 5201                      Zuid-Gelders
# 5202                      Zuid-Gelders
# 5203                              Zulu
#
#                                                category
# 0     subject.History.British_History.British_Histor...
# 1                     subject.People.Historical_figures
# 2                                     subject.Countries
# 3     subject.Geography.European_Geography.European_...
# 4                                subject.People.Artists
# ...                                                 ...
# 5199        subject.Science.Chemistry.Chemical_elements
# ...

# %%
links= pd.read_csv("wikispeedia_paths-and-graph/links.tsv", sep='\t', skiprows=11, header=None)
links.columns = ['linkSource', 'linkTarget']
links
# Out:
#                               linkSource      linkTarget
# 0       %C3%81ed%C3%A1n_mac_Gabr%C3%A1in            Bede
# 1       %C3%81ed%C3%A1n_mac_Gabr%C3%A1in         Columba
# 2       %C3%81ed%C3%A1n_mac_Gabr%C3%A1in  D%C3%A1l_Riata
# 3       %C3%81ed%C3%A1n_mac_Gabr%C3%A1in   Great_Britain
# 4       %C3%81ed%C3%A1n_mac_Gabr%C3%A1in         Ireland
# ...                                  ...             ...
# 119877                              Zulu    South_Africa
# 119878                              Zulu       Swaziland
# 119879                              Zulu  United_Kingdom
# 119880                              Zulu          Zambia
# 119881                              Zulu        Zimbabwe
#
# [119882 rows x 2 columns]

# %%
links.query("'Calendar' in linkSource")
# Out:
# Empty DataFrame
# Columns: [linkSource, linkTarget]
# Index: []

# %%
paths_finished = pd.read_csv("wikispeedia_paths-and-graph/paths_finished.tsv", sep='\t', skiprows=15, header=None)
paths_finished.columns = ['hashedIpAddress','timestamp','durationInSec','path','rating']
paths_finished
# Out:
#         hashedIpAddress   timestamp  durationInSec  \
# 0      6a3701d319fc3754  1297740409            166
# 1      3824310e536af032  1344753412             88
# 2      415612e93584d30e  1349298640            138
# 3      64dd5cd342e3780c  1265613925             37
# 4      015245d773376aab  1366730828            175
# ...                 ...         ...            ...
# 51313  15a13a1d66ef5456  1349231015             66
# 51314  2ef7ac844cefda58  1300254138            165
# 51315  12863abb7887f890  1385095372            228
# 51316  19f8284371753362  1298792567             56
# 51317  24b84602179de377  1318122701             30
#
#                                                     path  rating
# 0      14th_century;15th_century;16th_century;Pacific...     NaN
# 1      14th_century;Europe;Africa;Atlantic_slave_trad...     3.0
# 2      14th_century;Niger;Nigeria;British_Empire;Slav...     NaN
# 3         14th_century;Renaissance;Ancient_Greece;Greece     NaN
# ...

# %%
paths_finished['timestamp'].max()
# Out:
# np.int64(1389823250)

# %%
import datetime
datetime.datetime.utcfromtimestamp(paths_finished['timestamp'].max())
# Out:
# datetime.datetime(2014, 1, 15, 22, 0, 50)

# %%
with open("plaintext_articles/4th_century.txt") as f:
    fourth_century = f.read()
print(fourth_century)
# Out:
#    #copyright
#
# 4th century
#
# 2007 Schools Wikipedia Selection. Related subjects: General history
#
#    Centuries:      3rd century - 4th century - 5th century
#      Decades: 300s 310s 320s 330s 340s 350s 360s 370s 380s 390s
#
#    As a means of recording the passage of time, the 4th century (per the
#    Julian/ Gregorian calendar and anno Domini era) was that century which
#    lasted from 301 to 400.
#
# Overview
#
# Events
#
#    Contemporary bronze head of Constantine I.
#    Enlarge
#    Contemporary bronze head of Constantine I.
#      * 301: Armenia first to adopt Christianity as state religion
#      * 306– 337: Constantine I, ends persecution of Christians in the
#        Roman Empire, calls First Council of Nicaea, see also Constantinian
#        shift, Constantinople becomes new seat of government ( New Rome)
#      * 378: Battle of Adrianople
#      * 378– 395: Theodosius I, Roman emperor, bans pagan worship,
# ...
